# %% [markdown]
# <a href="https://colab.research.google.com/github/jenboland/DailyKnowledge/blob/master/Internal_Link_Script.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')


# Load the CSV file from Google Drive
# Make sure that this file exists and is in the correct location
file_path = '/content/drive/My Drive/custom_extraction_full_text.csv'
df = pd.read_csv(file_path)
print(df.shape)
# Display the first few rows of the DataFrame
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (1599, 4)
#                                              Address  Status Code Status  \
# 0                        https://eonetwork.org/blog/          200     OK
# 1                https://eonetwork.org/blog/?&page=1          200     OK
# 2                https://eonetwork.org/blog/?&page=2          200     OK
# 3  https://eonetwork.org/blog/why-it-s-critical-t...          200     OK
# 4                 https://eonetwork.org/blog/?page=1          200     OK
#
#                                               body 1
# 0  <div class="hero hero--tall-bkg dark-bg rich-t...
# 1  <div class="hero hero--tall-bkg dark-bg rich-t...
# 2  <div class="hero hero--tall-bkg dark-bg rich-t...
# 3  <div class="hero mb-0 dark-bg rich-text-area">...
# 4  <div class="hero hero--tall-bkg dark-bg rich-t...

# %%
# Drop rows where 'Address' column contains 'page='
df = df[~df['Address'].str.contains('page=', na=False)]
df.shape
# Out:
# (1199, 4)

# %%
# prompt: rename column body 1 to content

df = df.rename(columns={'body 1': 'content'})

# %%
df.head()
# Out:
#                                              Address  Status Code Status  \
# 0                        https://eonetwork.org/blog/          200     OK
# 3  https://eonetwork.org/blog/why-it-s-critical-t...          200     OK
# 5  https://eonetwork.org/blog/ready-fire-oops-how...          200     OK
# 7  https://eonetwork.org/blog/how-to-use-your-bus...          200     OK
# 8  https://eonetwork.org/blog/how-human-skills-su...          200     OK
#
#                                              content
# 0  <div class="hero hero--tall-bkg dark-bg rich-t...
# 3  <div class="hero mb-0 dark-bg rich-text-area">...
# 5  <div class="hero mb-0 dark-bg rich-text-area">...
# 7  <div class="hero mb-0 dark-bg rich-text-area">...
# 8  <div class="hero mb-0 dark-bg rich-text-area">...

# %%
def find_internal_link_opportunities(df):
    contents = df['content'].tolist()
    vectorizer = TfidfVectorizer()
    vectors = vectorizer.fit_transform(contents)
    csim = cosine_similarity(vectors)
    print("Shape of csim:", csim.shape)  # Debugging
    print("Number of rows in df:", len(df))  # Debugging
    return csim

def save_link_opportunities_to_csv(df, csim, threshold=0.5, output_file="internal_link_opportunities.csv"):
    rows = []

    for idx, row in df.iterrows():
        if idx >= csim.shape[0]:  # Prevent out-of-bounds error
            print(f"Skipping row {idx} due to mismatch with csim dimensions.")
            continue

        similar_indices = [i for i, score in enumerate(csim[idx]) if score > threshold and i != idx]
        if similar_indices:
            for i in similar_indices:
                rows.append({
                    "Page": row['Address'],
                    "Potential Internal Links": df.iloc[i]['Address'],
                    "Similarity": csim[idx][i]
                })

    output_df = pd.DataFrame(rows)
    output_df.to_csv(output_file, index=False)
    print(f"Internal link opportunities saved to {output_file}")

# %%
# Example usage:
# Assuming 'df' is a DataFrame with 'Address' and 'content' columns
csim = find_internal_link_opportunities(df)
save_link_opportunities_to_csv(df, csim, threshold=0.5)
# Out:
# Shape of csim: (1199, 1199)
# Number of rows in df: 1199
# Skipping row 1199 due to mismatch with csim dimensions.
# Skipping row 1200 due to mismatch with csim dimensions.
# Skipping row 1202 due to mismatch with csim dimensions.
# Skipping row 1203 due to mismatch with csim dimensions.
# Skipping row 1205 due to mismatch with csim dimensions.
# Skipping row 1206 due to mismatch with csim dimensions.
# Skipping row 1207 due to mismatch with csim dimensions.
# Skipping row 1208 due to mismatch with csim dimensions.
# Skipping row 1209 due to mismatch with csim dimensions.
# Skipping row 1211 due to mismatch with csim dimensions.
# Skipping row 1212 due to mismatch with csim dimensions.
# Skipping row 1213 due to mismatch with csim dimensions.
# Skipping row 1215 due to mismatch with csim dimensions.
# Skipping row 1217 due to mismatch with csim dimensions.
# Skipping row 1218 due to mismatch with csim dimensions.
# Skipping row 1219 due to mismatch with csim dimensions.
# Skipping row 1220 due to mismatch with csim dimensions.
# Skipping row 1221 due to mismatch with csim dimensions.
# Skipping row 1222 due to mismatch with csim dimensions.
# Skipping row 1224 due to mismatch with csim dimensions.
# Skipping row 1225 due to mismatch with csim dimensions.
# Skipping row 1226 due to mismatch with csim dimensions.
# Skipping row 1228 due to mismatch with csim dimensions.
# Skipping row 1229 due to mismatch with csim dimensions.
# Skipping row 1231 due to mismatch with csim dimensions.
# Skipping row 1232 due to mismatch with csim dimensions.
# Skipping row 1233 due to mismatch with csim dimensions.
# Skipping row 1234 due to mismatch with csim dimensions.
# Skipping row 1237 due to mismatch with csim dimensions.
# Skipping row 1238 due to mismatch with csim dimensions.
# Skipping row 1239 due to mismatch with csim dimensions.
# Skipping row 1240 due to mismatch with csim dimensions.
# Skipping row 1242 due to mismatch with csim dimensions.
# Skipping row 1243 due to mismatch with csim dimensions.
# Skipping row 1244 due to mismatch with csim dimensions.
# Skipping row 1246 due to mismatch with csim dimensions.
# Skipping row 1247 due to mismatch with csim dimensions.
# Skipping row 1248 due to mismatch with csim dimensions.
# Skipping row 1249 due to mismatch with csim dimensions.
# Skipping row 1251 due to mismatch with csim dimensions.
# Skipping row 1252 due to mismatch with csim dimensions.
# Skipping row 1254 due to mismatch with csim dimensions.
# Skipping row 1255 due to mismatch with csim dimensions.
# Skipping row 1256 due to mismatch with csim dimensions.
# Skipping row 1257 due to mismatch with csim dimensions.
# Skipping row 1259 due to mismatch with csim dimensions.
# Skipping row 1260 due to mismatch with csim dimensions.
# Skipping row 1261 due to mismatch with csim dimensions.
# Skipping row 1262 due to mismatch with csim dimensions.
# Skipping row 1263 due to mismatch with csim dimensions.
# Skipping row 1266 due to mismatch with csim dimensions.
# Skipping row 1267 due to mismatch with csim dimensions.
# Skipping row 1268 due to mismatch with csim dimensions.
# Skipping row 1269 due to mismatch with csim dimensions.
# Skipping row 1271 due to mismatch with csim dimensions.
# Skipping row 1272 due to mismatch with csim dimensions.
# Skipping row 1274 due to mismatch with csim dimensions.
# Skipping row 1275 due to mismatch with csim dimensions.
# Skipping row 1276 due to mismatch with csim dimensions.
# Skipping row 1277 due to mismatch with csim dimensions.
# Skipping row 1278 due to mismatch with csim dimensions.
# Skipping row 1280 due to mismatch with csim dimensions.
# Skipping row 1281 due to mismatch with csim dimensions.
# Skipping row 1282 due to mismatch with csim dimensions.
# Skipping row 1284 due to mismatch with csim dimensions.
# Skipping row 1286 due to mismatch with csim dimensions.
# Skipping row 1287 due to mismatch with csim dimensions.
# Skipping row 1288 due to mismatch with csim dimensions.
# Skipping row 1289 due to mismatch with csim dimensions.
# Skipping row 1291 due to mismatch with csim dimensions.
# Skipping row 1292 due to mismatch with csim dimensions.
# Skipping row 1293 due to mismatch with csim dimensions.
# Skipping row 1296 due to mismatch with csim dimensions.
# Skipping row 1297 due to mismatch with csim dimensions.
# Skipping row 1298 due to mismatch with csim dimensions.
# Skipping row 1299 due to mismatch with csim dimensions.
# Skipping row 1300 due to mismatch with csim dimensions.
# Skipping row 1301 due to mismatch with csim dimensions.
# Skipping row 1303 due to mismatch with csim dimensions.
# Skipping row 1304 due to mismatch with csim dimensions.
# Skipping row 1306 due to mismatch with csim dimensions.
# Skipping row 1307 due to mismatch with csim dimensions.
# Skipping row 1308 due to mismatch with csim dimensions.
# Skipping row 1309 due to mismatch with csim dimensions.
# Skipping row 1312 due to mismatch with csim dimensions.
# Skipping row 1313 due to mismatch with csim dimensions.
# Skipping row 1314 due to mismatch with csim dimensions.
# Skipping row 1315 due to mismatch with csim dimensions.
# Skipping row 1316 due to mismatch with csim dimensions.
# Skipping row 1318 due to mismatch with csim dimensions.
# Skipping row 1319 due to mismatch with csim dimensions.
# Skipping row 1320 due to mismatch with csim dimensions.
# Skipping row 1322 due to mismatch with csim dimensions.
# Skipping row 1323 due to mismatch with csim dimensions.
# Skipping row 1325 due to mismatch with csim dimensions.
# Skipping row 1326 due to mismatch with csim dimensions.
# Skipping row 1327 due to mismatch with csim dimensions.
# Skipping row 1329 due to mismatch with csim dimensions.
# Skipping row 1330 due to mismatch with csim dimensions.
# Skipping row 1331 due to mismatch with csim dimensions.
# Skipping row 1333 due to mismatch with csim dimensions.
# Skipping row 1334 due to mismatch with csim dimensions.
# Skipping row 1335 due to mismatch with csim dimensions.
# Skipping row 1336 due to mismatch with csim dimensions.
# Skipping row 1337 due to mismatch with csim dimensions.
# Skipping row 1339 due to mismatch with csim dimensions.
# Skipping row 1340 due to mismatch with csim dimensions.
# Skipping row 1341 due to mismatch with csim dimensions.
# Skipping row 1342 due to mismatch with csim dimensions.
# Skipping row 1344 due to mismatch with csim dimensions.
# Skipping row 1345 due to mismatch with csim dimensions.
# Skipping row 1346 due to mismatch with csim dimensions.
# Skipping row 1348 due to mismatch with csim dimensions.
# Skipping row 1350 due to mismatch with csim dimensions.
# Skipping row 1351 due to mismatch with csim dimensions.
# Skipping row 1353 due to mismatch with csim dimensions.
# Skipping row 1354 due to mismatch with csim dimensions.
# Skipping row 1355 due to mismatch with csim dimensions.
# Skipping row 1357 due to mismatch with csim dimensions.
# Skipping row 1358 due to mismatch with csim dimensions.
# Skipping row 1359 due to mismatch with csim dimensions.
# Skipping row 1360 due to mismatch with csim dimensions.
# Skipping row 1361 due to mismatch with csim dimensions.
# Skipping row 1362 due to mismatch with csim dimensions.
# Skipping row 1364 due to mismatch with csim dimensions.
# Skipping row 1365 due to mismatch with csim dimensions.
# Skipping row 1366 due to mismatch with csim dimensions.
# Skipping row 1368 due to mismatch with csim dimensions.
# Skipping row 1369 due to mismatch with csim dimensions.
# Skipping row 1370 due to mismatch with csim dimensions.
# Skipping row 1372 due to mismatch with csim dimensions.
# Skipping row 1373 due to mismatch with csim dimensions.
# Skipping row 1374 due to mismatch with csim dimensions.
# Skipping row 1375 due to mismatch with csim dimensions.
# Skipping row 1376 due to mismatch with csim dimensions.
# Skipping row 1379 due to mismatch with csim dimensions.
# Skipping row 1381 due to mismatch with csim dimensions.
# Skipping row 1382 due to mismatch with csim dimensions.
# Skipping row 1383 due to mismatch with csim dimensions.
# Skipping row 1384 due to mismatch with csim dimensions.
# Skipping row 1385 due to mismatch with csim dimensions.
# Skipping row 1387 due to mismatch with csim dimensions.
# Skipping row 1388 due to mismatch with csim dimensions.
# Skipping row 1389 due to mismatch with csim dimensions.
# Skipping row 1390 due to mismatch with csim dimensions.
# Skipping row 1391 due to mismatch with csim dimensions.
# Skipping row 1392 due to mismatch with csim dimensions.
# Skipping row 1395 due to mismatch with csim dimensions.
# Skipping row 1396 due to mismatch with csim dimensions.
# Skipping row 1397 due to mismatch with csim dimensions.
# Skipping row 1398 due to mismatch with csim dimensions.
# Skipping row 1400 due to mismatch with csim dimensions.
# Skipping row 1401 due to mismatch with csim dimensions.
# Skipping row 1403 due to mismatch with csim dimensions.
# Skipping row 1404 due to mismatch with csim dimensions.
# Skipping row 1405 due to mismatch with csim dimensions.
# Skipping row 1407 due to mismatch with csim dimensions.
# Skipping row 1408 due to mismatch with csim dimensions.
# Skipping row 1409 due to mismatch with csim dimensions.
# Skipping row 1412 due to mismatch with csim dimensions.
# Skipping row 1413 due to mismatch with csim dimensions.
# Skipping row 1414 due to mismatch with csim dimensions.
# Skipping row 1415 due to mismatch with csim dimensions.
# Skipping row 1416 due to mismatch with csim dimensions.
# Skipping row 1418 due to mismatch with csim dimensions.
# Skipping row 1419 due to mismatch with csim dimensions.
# Skipping row 1420 due to mismatch with csim dimensions.
# Skipping row 1421 due to mismatch with csim dimensions.
# Skipping row 1423 due to mismatch with csim dimensions.
# Skipping row 1425 due to mismatch with csim dimensions.
# Skipping row 1426 due to mismatch with csim dimensions.
# Skipping row 1427 due to mismatch with csim dimensions.
# Skipping row 1428 due to mismatch with csim dimensions.
# Skipping row 1429 due to mismatch with csim dimensions.
# Skipping row 1431 due to mismatch with csim dimensions.
# Skipping row 1432 due to mismatch with csim dimensions.
# Skipping row 1433 due to mismatch with csim dimensions.
# Skipping row 1435 due to mismatch with csim dimensions.
# Skipping row 1436 due to mismatch with csim dimensions.
# Skipping row 1438 due to mismatch with csim dimensions.
# Skipping row 1440 due to mismatch with csim dimensions.
# Skipping row 1441 due to mismatch with csim dimensions.
# Skipping row 1442 due to mismatch with csim dimensions.
# Skipping row 1443 due to mismatch with csim dimensions.
# Skipping row 1445 due to mismatch with csim dimensions.
# Skipping row 1446 due to mismatch with csim dimensions.
# Skipping row 1447 due to mismatch with csim dimensions.
# Skipping row 1448 due to mismatch with csim dimensions.
# Skipping row 1449 due to mismatch with csim dimensions.
# Skipping row 1451 due to mismatch with csim dimensions.
# Skipping row 1452 due to mismatch with csim dimensions.
# Skipping row 1454 due to mismatch with csim dimensions.
# Skipping row 1456 due to mismatch with csim dimensions.
# Skipping row 1457 due to mismatch with csim dimensions.
# Skipping row 1458 due to mismatch with csim dimensions.
# Skipping row 1460 due to mismatch with csim dimensions.
# Skipping row 1461 due to mismatch with csim dimensions.
# Skipping row 1462 due to mismatch with csim dimensions.
# Skipping row 1464 due to mismatch with csim dimensions.
# Skipping row 1465 due to mismatch with csim dimensions.
# Skipping row 1466 due to mismatch with csim dimensions.
# Skipping row 1467 due to mismatch with csim dimensions.
# Skipping row 1469 due to mismatch with csim dimensions.
# Skipping row 1470 due to mismatch with csim dimensions.
# Skipping row 1472 due to mismatch with csim dimensions.
# Skipping row 1473 due to mismatch with csim dimensions.
# Skipping row 1474 due to mismatch with csim dimensions.
# Skipping row 1475 due to mismatch with csim dimensions.
# Skipping row 1477 due to mismatch with csim dimensions.
# Skipping row 1478 due to mismatch with csim dimensions.
# Skipping row 1479 due to mismatch with csim dimensions.
# Skipping row 1480 due to mismatch with csim dimensions.
# Skipping row 1481 due to mismatch with csim dimensions.
# Skipping row 1484 due to mismatch with csim dimensions.
# Skipping row 1485 due to mismatch with csim dimensions.
# Skipping row 1486 due to mismatch with csim dimensions.
# Skipping row 1488 due to mismatch with csim dimensions.
# Skipping row 1489 due to mismatch with csim dimensions.
# Skipping row 1490 due to mismatch with csim dimensions.
# Skipping row 1491 due to mismatch with csim dimensions.
# Skipping row 1493 due to mismatch with csim dimensions.
# Skipping row 1494 due to mismatch with csim dimensions.
# Skipping row 1496 due to mismatch with csim dimensions.
# Skipping row 1497 due to mismatch with csim dimensions.
# Skipping row 1498 due to mismatch with csim dimensions.
# Skipping row 1500 due to mismatch with csim dimensions.
# Skipping row 1501 due to mismatch with csim dimensions.
# Skipping row 1503 due to mismatch with csim dimensions.
# Skipping row 1504 due to mismatch with csim dimensions.
# Skipping row 1505 due to mismatch with csim dimensions.
# Skipping row 1506 due to mismatch with csim dimensions.
# Skipping row 1507 due to mismatch with csim dimensions.
# Skipping row 1509 due to mismatch with csim dimensions.
# Skipping row 1510 due to mismatch with csim dimensions.
# Skipping row 1511 due to mismatch with csim dimensions.
# Skipping row 1512 due to mismatch with csim dimensions.
# Skipping row 1514 due to mismatch with csim dimensions.
# Skipping row 1515 due to mismatch with csim dimensions.
# Skipping row 1517 due to mismatch with csim dimensions.
# Skipping row 1518 due to mismatch with csim dimensions.
# Skipping row 1519 due to mismatch with csim dimensions.
# Skipping row 1520 due to mismatch with csim dimensions.
# Skipping row 1521 due to mismatch with csim dimensions.
# Skipping row 1524 due to mismatch with csim dimensions.
# Skipping row 1525 due to mismatch with csim dimensions.
# Skipping row 1527 due to mismatch with csim dimensions.
# Skipping row 1528 due to mismatch with csim dimensions.
# Skipping row 1529 due to mismatch with csim dimensions.
# Skipping row 1530 due to mismatch with csim dimensions.
# Skipping row 1532 due to mismatch with csim dimensions.
# Skipping row 1533 due to mismatch with csim dimensions.
# Skipping row 1534 due to mismatch with csim dimensions.
# Skipping row 1535 due to mismatch with csim dimensions.
# Skipping row 1537 due to mismatch with csim dimensions.
# Skipping row 1538 due to mismatch with csim dimensions.
# Skipping row 1539 due to mismatch with csim dimensions.
# Skipping row 1541 due to mismatch with csim dimensions.
# Skipping row 1542 due to mismatch with csim dimensions.
# Skipping row 1543 due to mismatch with csim dimensions.
# Skipping row 1545 due to mismatch with csim dimensions.
# Skipping row 1547 due to mismatch with csim dimensions.
# Skipping row 1548 due to mismatch with csim dimensions.
# Skipping row 1549 due to mismatch with csim dimensions.
# Skipping row 1550 due to mismatch with csim dimensions.
# Skipping row 1551 due to mismatch with csim dimensions.
# Skipping row 1553 due to mismatch with csim dimensions.
# Skipping row 1554 due to mismatch with csim dimensions.
# Skipping row 1556 due to mismatch with csim dimensions.
# Skipping row 1557 due to mismatch with csim dimensions.
# Skipping row 1558 due to mismatch with csim dimensions.
# Skipping row 1559 due to mismatch with csim dimensions.
# Skipping row 1561 due to mismatch with csim dimensions.
# Skipping row 1562 due to mismatch with csim dimensions.
# Skipping row 1563 due to mismatch with csim dimensions.
# Skipping row 1564 due to mismatch with csim dimensions.
# Skipping row 1565 due to mismatch with csim dimensions.
# Skipping row 1566 due to mismatch with csim dimensions.
# Skipping row 1569 due to mismatch with csim dimensions.
# Skipping row 1570 due to mismatch with csim dimensions.
# Skipping row 1571 due to mismatch with csim dimensions.
# Skipping row 1572 due to mismatch with csim dimensions.
# Skipping row 1574 due to mismatch with csim dimensions.
# Skipping row 1576 due to mismatch with csim dimensions.
# Skipping row 1577 due to mismatch with csim dimensions.
# Skipping row 1579 due to mismatch with csim dimensions.
# Skipping row 1580 due to mismatch with csim dimensions.
# Skipping row 1581 due to mismatch with csim dimensions.
# Skipping row 1582 due to mismatch with csim dimensions.
# Skipping row 1583 due to mismatch with csim dimensions.
# Skipping row 1585 due to mismatch with csim dimensions.
# Skipping row 1587 due to mismatch with csim dimensions.
# Skipping row 1588 due to mismatch with csim dimensions.
# Skipping row 1589 due to mismatch with csim dimensions.
# Skipping row 1590 due to mismatch with csim dimensions.
# Skipping row 1591 due to mismatch with csim dimensions.
# Skipping row 1592 due to mismatch with csim dimensions.
# Skipping row 1593 due to mismatch with csim dimensions.
# Skipping row 1594 due to mismatch with csim dimensions.
# Skipping row 1596 due to mismatch with csim dimensions.
# Skipping row 1597 due to mismatch with csim dimensions.
# Skipping row 1598 due to mismatch with csim dimensions.
# Internal link opportunities saved to internal_link_opportunities.csv
